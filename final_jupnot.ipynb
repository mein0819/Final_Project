# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
file_path1 = 'clean_homes.csv'
NHI_df = pd.read_csv(file_path1)
NHI_df.head(10)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
# 5    394974         5                    Philadelphia, PA        Msa
# 6    394692         6                         Houston, TX        Msa
# 7    395209         7                      Washington, DC        Msa
# 8    394856         8           Miami-Fort Lauderdale, FL        Msa
# 9    394347         9                         Atlanta, GA        Msa
#
#   StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0       NaN    128454.0    128801.0    129167.0    129911.0    130662.0  ...
# ...

# %%
NHI_df['RegionName'] = [re.sub("(.*),.*", "\\1", str(x)) for x in NHI_df['RegionName']]

# %%
NHI_df.head(10)
# Out:
#    RegionID  SizeRank                      RegionName RegionType StateName  \
# 0    102001         0                   United States    Country       NaN
# 1    394913         1                        New York        Msa        NY
# 2    753899         2  Los Angeles-Long Beach-Anaheim        Msa        CA
# 3    394463         3                         Chicago        Msa        IL
# 4    394514         4               Dallas-Fort Worth        Msa        TX
# 5    394974         5                    Philadelphia        Msa        PA
# 6    394692         6                         Houston        Msa        TX
# 7    395209         7                      Washington        Msa        DC
# 8    394856         8           Miami-Fort Lauderdale        Msa        FL
# 9    394347         9                         Atlanta        Msa        GA
#
#    2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0    128454.0    128801.0    129167.0    129911.0    130662.0  ...
# ...

# %%
Date= NHI_df.loc[:, "2022-06-30"]
NHI_df.melt(id_vars=["RegionID", "SizeRank", "RegionName", "RegionType", "StateName"],
    var_name="Date",
    value_name="Value")
# Out:
#         RegionID  SizeRank                      RegionName RegionType  \
# 0         102001         0                   United States    Country
# 1         394913         1                        New York        Msa
# 2         753899         2  Los Angeles-Long Beach-Anaheim        Msa
# 3         394463         3                         Chicago        Msa
# 4         394514         4               Dallas-Fort Worth        Msa
# ...          ...       ...                             ...        ...
# 245155    394767       929                          Lamesa        Msa
# 245156    753874       930                           Craig        Msa
# 245157    394968       931                           Pecos        Msa
# 245158    395188       932                          Vernon        Msa
# 245159    394743       933                       Ketchikan        Msa
#
#        StateName        Date     Value
# 0            NaN  2000-01-31  128454.0
# 1             NY  2000-01-31  225516.0
# ...
